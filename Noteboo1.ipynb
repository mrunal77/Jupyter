# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import plotly as px

# %%
dataset1 = px.data.election()

# %%
type(dataset1)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset1.head(10)
# Out:
#                      district  Coderre  Bergeron  Joly  total    winner  \
# 0          101-Bois-de-Liesse     2481      1829  3024   7334      Joly
# 1       102-Cap-Saint-Jacques     2525      1163  2675   6363      Joly
# 2        11-Sault-au-Récollet     3348      2770  2532   8650   Coderre
# 3                111-Mile-End     1734      4782  2514   9030  Bergeron
# 4              112-DeLorimier     1770      5933  3044  10747  Bergeron
# 5            113-Jeanne-Mance     1455      3599  2316   7370  Bergeron
# 6            12-Saint-Sulpice     3252      2521  2543   8316   Coderre
# 7  121-La Pointe-aux-Prairies     5456      1760  3330  10546   Coderre
# 8     122-Pointe-aux-Trembles     4734      1879  2852   9465   Coderre
# 9    123-Rivière-des-Prairies     5737       958  1656   8351   Coderre
#
#       result  district_id
# 0  plurality          101
# 1  plurality          102
# 2  plurality           11
# 3   majority          111
# 4   majority          112
# ...

# %%
(dataset1[dataset1["district_id"]>100]).head(10)
# Out:
#                       district  Coderre  Bergeron  Joly  total    winner  \
# 0           101-Bois-de-Liesse     2481      1829  3024   7334      Joly
# 1        102-Cap-Saint-Jacques     2525      1163  2675   6363      Joly
# 3                 111-Mile-End     1734      4782  2514   9030  Bergeron
# 4               112-DeLorimier     1770      5933  3044  10747  Bergeron
# 5             113-Jeanne-Mance     1455      3599  2316   7370  Bergeron
# 7   121-La Pointe-aux-Prairies     5456      1760  3330  10546   Coderre
# 8      122-Pointe-aux-Trembles     4734      1879  2852   9465   Coderre
# 9     123-Rivière-des-Prairies     5737       958  1656   8351   Coderre
# 11           131-Saint-Édouard     1827      6408  2815  11050  Bergeron
# 12      132-Étienne-Desmarteau     2331      5748  2788  10867  Bergeron
#
#        result  district_id
# 0   plurality          101
# 1   plurality          102
# 3    majority          111
# 4    majority          112
# ...

# %%
datatop10 = (dataset1[dataset1["district_id"]>100])

# %%
datatop10.sort_values('district_id', ascending= False).head(20)
# Out:
#                                              district  Coderre  Bergeron  \
# 30                                 194-Parc-Extension     2420      1793
# 29                                       193-Villeray     2201      5819
# 28                              192-François-Perrault     2878      2666
# 27                                   191-Saint-Michel     3668       984
# 26                                   183-Sainte-Marie     1347      2827
# 25                                  182-Saint-Jacques     1906      2169
# 24                                   181-Peter-McGill     1451       754
# 23                           172-Desmarchais-Crawford     2476      2631
# 22                      171-ChamplainL'Île-des-Soeurs     3347      2562
# 21                                162-Saint-PaulÉmard     2566      2092
# 20  161-Saint-HenriPetite-BourgognePointe-Saint-Ch...     2432      3368
# 19                            152-Saint-Léonard-Ouest     5387      1184
# ...

# %%
(dataset1[(dataset1["district_id"]>100) & (dataset1['total']<7000)]).head(10)
# Out:
#                  district  Coderre  Bergeron  Joly  total    winner  \
# 1   102-Cap-Saint-Jacques     2525      1163  2675   6363      Joly
# 18  151-Saint-Léonard-Est     3931       882  1641   6454   Coderre
# 24       181-Peter-McGill     1451       754  1894   4099      Joly
# 25      182-Saint-Jacques     1906      2169  2282   6357      Joly
# 26       183-Sainte-Marie     1347      2827  2271   6445  Bergeron
# 27       191-Saint-Michel     3668       984  1220   5872   Coderre
# 30     194-Parc-Extension     2420      1793  1402   5615   Coderre
#
#        result  district_id
# 1   plurality          102
# 18   majority          151
# 24  plurality          181
# 25  plurality          182
# 26  plurality          183
# 27   majority          191
# 30  plurality          194

# %%
((dataset1[(dataset1["district_id"]>100) & (dataset1['total']<7000)])).sort_values('district_id', ascending= False).head(10)
# Out:
#                  district  Coderre  Bergeron  Joly  total    winner  \
# 30     194-Parc-Extension     2420      1793  1402   5615   Coderre
# 27       191-Saint-Michel     3668       984  1220   5872   Coderre
# 26       183-Sainte-Marie     1347      2827  2271   6445  Bergeron
# 25      182-Saint-Jacques     1906      2169  2282   6357      Joly
# 24       181-Peter-McGill     1451       754  1894   4099      Joly
# 18  151-Saint-Léonard-Est     3931       882  1641   6454   Coderre
# 1   102-Cap-Saint-Jacques     2525      1163  2675   6363      Joly
#
#        result  district_id
# 30  plurality          194
# 27   majority          191
# 26  plurality          183
# 25  plurality          182
# 24  plurality          181
# 18   majority          151
# 1   plurality          102
